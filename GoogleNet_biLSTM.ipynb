# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import torch
import torchvision
from PIL import Image
import IPython.display

# %%
imagesFilepath = "flickr\Flickr_Data\Images"
number_of_latent_variables = 1024

# %%
# Create a list of jpg image filepaths
found_jpg_filepaths = []
directory_contents = os.listdir(imagesFilepath)
for content in directory_contents:
    filepath = os.path.join(imagesFilepath, content)
    if filepath.endswith('.jpg'):
        found_jpg_filepaths.append(filepath)
print(found_jpg_filepaths[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5136\3711908269.py in <module>
#       1 # Create a list of jpg image filepaths
#       2 found_jpg_filepaths = []
# ----> 3 directory_contents = os.listdir(imagesFilepath)
#       4 for content in directory_contents:
#       5     filepath = os.path.join(imagesFilepath, content)
#
# NameError: name 'os' is not defined

# %%
training_images_filepath = "flickr\Flickr_Data\Flickr_TextData\Flickr_8k.trainImages.txt"
validation_images_filepath = "flickr\Flickr_Data\Flickr_TextData\Flickr_8k.devImages.txt"
pretokenized_descriptions_filepath = "tokenized_descriptions_flickr.csv"
vocabulary_filepath = 'vocabulary_flickr.csv'
words2vec_dictionary_filepath = 'words2vec/flickr_words2vec.csv'
latent_representation_filepath = 'flickr_latent_googleNet.csv'

latent_representationDf = pd.read_csv(latent_representation_filepath)
tokenized_descriptionsDf = pd.read_csv(pretokenized_descriptions_filepath)

# %%
with open(training_images_filepath, 'r') as train_images_file:
    train_images_list = [line.strip() for line in train_images_file]

# %%
def LoadVocabulary(vocabularyFilepath):
    word_to_index_dict = {}
    index_to_word_dict = {}
    vocabDf = pd.read_csv(vocabularyFilepath)
    for i, row in vocabDf.iterrows():
        index = row['index']
        word = row['word']
        word_to_index_dict[word] = index
        index_to_word_dict[index] = word
    return word_to_index_dict, index_to_word_dict

word_to_index_dict, index_to_word_dict = LoadVocabulary(vocabulary_filepath)

# %%
word2vecDf = pd.read_csv(words2vec_dictionary_filepath)
embedding_dimension = 128
word_to_embedding_dict = {word2vecDf.iloc[i]['word'] : word2vecDf.loc[i, 'e0': 'e{}'.format(embedding_dimension - 1)].tolist()
                              for i in range(len(word2vecDf))}

# %%
import en_core_web_sm
import re
import string

nlp = en_core_web_sm.load()

def Tokenize(text, nlp):
    text = re.sub(r"[^\x00-\x7F]+", " ", text)
    regex = re.compile('[' + re.escape(string.punctuation) + '0-9\\r\\t\\n]')  # Remove punctuation and numbers
    nopunct = regex.sub(" ", text.lower())
    tokens = [token.text for token in nlp.tokenizer(nopunct) if not token.text.isspace()]
    return tokens

# %%
from torch.utils.data import Dataset, DataLoader
import random

class CaptionGenerationDataset(Dataset):
    def __init__(self,
                 image_filenames,
                 image_filename_to_latent_variables,
                 image_filename_to_tokenized_descriptions_list,
                 endOfSeqIndex,
                 notSetIndex,
                 vocabulary_size,
                 index_to_word_dict,
                 word_to_embedding_dict
                 ):
        self.image_filenames = image_filenames
        self.image_filename_to_latent_variables = image_filename_to_latent_variables
        self.image_filename_to_tokenized_descriptions_list = image_filename_to_tokenized_descriptions_list
        self.endOfSeqIndex = endOfSeqIndex
        self.notSetIndex = notSetIndex
        self.vocabulary_size = vocabulary_size
        self.index_to_word_dict = index_to_word_dict
        self.word_to_embedding_dict = word_to_embedding_dict

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        if idx >= len(self.image_filenames):
            raise IndexError("CaptionGenerationDataset.__getitem__(): Index {} is greater than the number of images ({})".format(idx, len(self.image_filenames)))
        filename = self.image_filenames[idx]
        latent_variables = self.image_filename_to_latent_variables[filename]
        # Build a tensor
        latent_variablesTsr = torch.zeros(len(latent_variables))
        for i in range(len(latent_variables)):
            latent_variablesTsr[i] = latent_variables[i]
        # Randomly choose one of the descriptions
        description = random.choice(self.image_filename_to_tokenized_descriptions_list[filename])
        lastIndex = self.IndexOfEndOfSeq(description)
        chopIndex = random.randint(0, lastIndex) - 1 # The last index of the chopped description
        choppedDescription = [self.notSetIndex] * len(description)
        if chopIndex >= 0:
            for i in range(chopIndex + 1):
                choppedDescription[i] = description[i]

        embedding_dim = len(self.word_to_embedding_dict[ self.index_to_word_dict[0] ]) # Length of the embedding of the 1st word
        embeddedChoppedDescriptionTsr = torch.zeros((len(description), embedding_dim))
        for wordPosn in range(len(choppedDescription)):
            embedding = self.word_to_embedding_dict[ self.index_to_word_dict[choppedDescription[wordPosn]]]
            embeddedChoppedDescriptionTsr[wordPosn] = torch.tensor(embedding)

        next_word_index = description[chopIndex + 1]

        return ( (latent_variablesTsr, embeddedChoppedDescriptionTsr), next_word_index)

    def IndexOfEndOfSeq(self, description_list):
        foundIndex = -1
        for candidateNdx in range(len(description_list)):
            if description_list[candidateNdx] == self.endOfSeqIndex:
                foundIndex = candidateNdx
                break
        if foundIndex == -1:
            return len(description_list) - 1
        else:
            return foundIndex
        
def ImageFilenameToLatentVariables(latent_varDf):
    image_filename_to_latent_variables = {}
    for i, row in latent_varDf.iterrows():
        filepath = latent_varDf.iloc[i][0]
        filename = os.path.basename(filepath)
        latent_variables = list(latent_varDf.iloc[i][1:])
        image_filename_to_latent_variables[filename] = latent_variables
    return image_filename_to_latent_variables

image_filename_to_latent_variables = ImageFilenameToLatentVariables(latent_representationDf)

def ImageFilenameToTokenizedDescriptionsList(descriptionsDF):
    image_filename_to_tokenized_description = {}
    for i, row in descriptionsDF.iterrows():
        filename = descriptionsDF.iloc[i][0]
        tokenized_description = list(descriptionsDF.iloc[i][1:])
        if filename in image_filename_to_tokenized_description:
            image_filename_to_tokenized_description[filename].append(tokenized_description)
        else:
            image_filename_to_tokenized_description[filename] = [tokenized_description]
    return image_filename_to_tokenized_description

image_filename_to_tokenized_descriptions_list = ImageFilenameToTokenizedDescriptionsList(tokenized_descriptionsDf)

lstm_train_dataset = CaptionGenerationDataset(
        train_images_list,
        image_filename_to_latent_variables,
        image_filename_to_tokenized_descriptions_list,
        word_to_index_dict['ENDOFSEQ'],
        word_to_index_dict['NOTSET'],
        len(word_to_index_dict),
        index_to_word_dict,
        word_to_embedding_dict
    )

# %%
with open(validation_images_filepath, 'r') as valid_images_file:
    validation_images_list = [line.strip() for line in valid_images_file]
lstm_validation_dataset = CaptionGenerationDataset(
        validation_images_list,
        image_filename_to_latent_variables,
        image_filename_to_tokenized_descriptions_list,
        word_to_index_dict['ENDOFSEQ'],
        word_to_index_dict['NOTSET'],
        len(word_to_index_dict),
        index_to_word_dict,
        word_to_embedding_dict
    )

# %%
useCuda = torch.cuda.is_available()
class BiLSTM_fixed_embedding(torch.nn.Module):
    def __init__(self, embedding_dim, lstm_hidden_dim,
                 num_lstm_layers, image_latent_dim,
                 vocab_size,
                 dropoutProportion=0.52):
        super(BiLSTM_fixed_embedding, self).__init__()
        self.embedding_dim = embedding_dim
        self.lstm = torch.nn.LSTM(embedding_dim, lstm_hidden_dim, num_lstm_layers, batch_first=True, bidirectional=True)  # Bidirectional LSTM
        self.dropout = torch.nn.Dropout(dropoutProportion)
        self.linear = torch.nn.Linear(lstm_hidden_dim * 2 + image_latent_dim, vocab_size)  # Adjusting linear layer input size for bidirectional LSTM


    def forward(self, image_latentTsr, embeddedChoppedDescriptionTsr):
        aggregated_h, (ht, ct) = self.lstm(embeddedChoppedDescriptionTsr)
        # Concatenating the final hidden states from both directions
        concat_latent = torch.cat((torch.nn.functional.normalize(ht[-2,:,:]), torch.nn.functional.normalize(ht[-1,:,:]), torch.nn.functional.normalize(image_latentTsr)), dim=1)  # Using ht[-2,:,:] and ht[-1,:,:] for bidirectional LSTM
        outputTsr = self.linear(self.dropout(concat_latent))
        return outputTsr
    
    
    def Caption(self, latentVariablesTsr, maximumLength, word_to_embedding_dict, index_to_word_dict, endOfSeqIndex, useCuda):
        notSetEmbedding = word_to_embedding_dict['NOTSET']
        embeddedChoppedDescriptionTsr = torch.zeros((maximumLength, self.embedding_dim))
        for i in range(maximumLength):
            embeddedChoppedDescriptionTsr[i] = torch.tensor(notSetEmbedding)
        endOfSeqIsFound = False
        runningNdx = 0
        caption_words = []
        while not endOfSeqIsFound and runningNdx < maximumLength:
            if useCuda:
                latentVariablesTsr = latentVariablesTsr.cuda()
                embeddedChoppedDescriptionTsr = embeddedChoppedDescriptionTsr.cuda()
            outputTsr = self.forward(latentVariablesTsr.unsqueeze(0), embeddedChoppedDescriptionTsr.unsqueeze(0))
            next_word_index = torch.argmax(outputTsr[0]).item()
            caption_words.append(index_to_word_dict[next_word_index])
            next_word = index_to_word_dict[next_word_index]
            embeddedChoppedDescriptionTsr[runningNdx] = torch.tensor(word_to_embedding_dict[next_word])
            runningNdx += 1
            if next_word_index == endOfSeqIndex:
                endOfSeqIsFound = True
        return caption_words

lstm_hidden_dimension = 32
lstm_number_of_layers = 2
dropoutProportion = 0.52
lstm_model =  BiLSTM_fixed_embedding(
        embedding_dim=embedding_dimension,
        lstm_hidden_dim=lstm_hidden_dimension,
        num_lstm_layers=lstm_number_of_layers,
        image_latent_dim=number_of_latent_variables,
        vocab_size=len(word_to_index_dict),
        dropoutProportion=dropoutProportion
    )

if useCuda:
    lstm_model = lstm_model.cuda()

# %%
def TestSample(index, validation_images_list, image_filename_to_latent_variables, model,
               index_to_word_dict,
               word_to_embedding_dict,
               sequence_length=40,
               endOfSeqIndex=0,
               useCuda=True):
    sample_filename = validation_images_list[index]
    sample_latentVariablesTsr = torch.FloatTensor(image_filename_to_latent_variables[sample_filename])
    if useCuda:
        sample_latentVariablesTsr = sample_latentVariablesTsr.cuda()
    sample_words = model.Caption(
        latentVariablesTsr=sample_latentVariablesTsr,
        maximumLength=sequence_length,
        word_to_embedding_dict=word_to_embedding_dict,
        index_to_word_dict=index_to_word_dict,
        endOfSeqIndex=endOfSeqIndex,
        useCuda=useCuda
    )
    return sample_words

validation_sample_0_Ndx = 0
validation_sample_100_Ndx = 100
IPython.display.Image(os.path.join(imagesFilepath, validation_images_list[validation_sample_0_Ndx]))

# %%
best_model_filepath = 'bilstm_gNet_flickr.pth'

# %%
import sys

parameters = filter(lambda p: p.requires_grad, lstm_model.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.00028)
lossFcn = torch.nn.CrossEntropyLoss()
train_dataLoader = DataLoader(lstm_train_dataset, batch_size=16, shuffle=True)
validation_dataLoader = DataLoader(lstm_validation_dataset, batch_size=lstm_validation_dataset.__len__())

lowestValidationLoss = sys.float_info.max
for epoch in range(1, 500 + 1):
    lstm_model.train()
    loss_sum = 0.0
    numberOfBatches = 0
    for ( (latent_variablesTsr, chopped_descriptionTsr), target_next_word) in train_dataLoader:
        if numberOfBatches % 4 == 1:
            print (".", end="", flush=True)
        if useCuda:
            latent_variablesTsr = latent_variablesTsr.cuda()
            chopped_descriptionTsr = chopped_descriptionTsr.cuda()
            target_next_word = target_next_word.cuda()
        predicted_next_word = lstm_model(latent_variablesTsr, chopped_descriptionTsr)
        optimizer.zero_grad()
        loss = lossFcn(predicted_next_word, target_next_word)
        loss.backward()
        optimizer.step()
        loss_sum += loss.item()
        numberOfBatches += 1
    train_loss = loss_sum/numberOfBatches
    print ("\nepoch {}: train_loss = {}".format(epoch, train_loss))

    # Validation
    lstm_model.eval()
    sample_0_words = TestSample(validation_sample_0_Ndx, validation_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
    print ("sample_0_words = {}".format(sample_0_words))
    sample_100_words = TestSample(validation_sample_100_Ndx, validation_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
    print ("sample_100_words = {}".format(sample_100_words))
    
    for ((validation_latent_variablesTsr, validation_chopped_descriptionTsr), validation_target_next_word) in validation_dataLoader:
        if useCuda:
            validation_latent_variablesTsr = validation_latent_variablesTsr.cuda()
            validation_chopped_descriptionTsr = validation_chopped_descriptionTsr.cuda()
            validation_target_next_word = validation_target_next_word.cuda()
        validation_predicted_next_word = lstm_model(validation_latent_variablesTsr, validation_chopped_descriptionTsr)
        validation_loss = lossFcn(validation_predicted_next_word, validation_target_next_word).item()
    print ("validation_loss = {}".format(validation_loss))

    if validation_loss < lowestValidationLoss:
        lowestValidationLoss = validation_loss
        torch.save(lstm_model.state_dict(), best_model_filepath)
# Out:
# ..............................................................................................
# epoch 1: train_loss = 7.044143374125163
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.95140266418457
# ..............................................................................................
# epoch 2: train_loss = 5.543367182413737
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.36272668838501
# ..............................................................................................
# epoch 3: train_loss = 5.380369899113973
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.181481838226318
# ..............................................................................................
# epoch 4: train_loss = 5.310733088175455
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.245276927947998
# ..............................................................................................
# epoch 5: train_loss = 5.341710644404094
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'ENDOFSEQ']
# validation_loss = 5.124878883361816
# ..............................................................................................
# epoch 6: train_loss = 5.159583968480428
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'ENDOFSEQ']
# validation_loss = 5.113815784454346
# ..............................................................................................
# epoch 7: train_loss = 5.084842525482178
# sample_0_words = ['a', 'a', 'a', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'a', 'a', 'a', 'ENDOFSEQ']
# validation_loss = 4.9750471115112305
# ..............................................................................................
# epoch 8: train_loss = 4.971918784459432
# sample_0_words = ['a', 'a', 'a', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'a', 'a', 'a', 'ENDOFSEQ']
# validation_loss = 4.952200889587402
# ..............................................................................................
# epoch 9: train_loss = 4.95239255396525
# sample_0_words = ['a', 'man', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.878207206726074
# ..............................................................................................
# epoch 10: train_loss = 4.871270211537679
# sample_0_words = ['a', 'man', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.75741720199585
# ..............................................................................................
# epoch 11: train_loss = 4.746354822794596
# sample_0_words = ['a', 'man', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.7425689697265625
# ..............................................................................................
# epoch 12: train_loss = 4.82116056505839
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.622779369354248
# ..............................................................................................
# epoch 13: train_loss = 4.7598758322397865
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.824528694152832
# ..............................................................................................
# epoch 14: train_loss = 4.754194253921509
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.702292442321777
# ..............................................................................................
# epoch 15: train_loss = 4.67489888827006
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.656033992767334
# ..............................................................................................
# epoch 16: train_loss = 4.631832652409871
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.632083892822266
# ..............................................................................................
# epoch 17: train_loss = 4.621232721964518
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.5289201736450195
# ..............................................................................................
# epoch 18: train_loss = 4.616915632883708
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.517387866973877
# ..............................................................................................
# epoch 19: train_loss = 4.578685539245606
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.5623626708984375
# ..............................................................................................
# epoch 20: train_loss = 4.569508768081665
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.440248012542725
# ..............................................................................................
# epoch 21: train_loss = 4.533698106765747
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# validation_loss = 4.596370220184326
# ..............................................................................................
# epoch 22: train_loss = 4.5267649815877276
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'and', 'a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.638725280761719
# ..............................................................................................
# epoch 23: train_loss = 4.526024059931437
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'and', 'a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.4010820388793945
# ..............................................................................................
# epoch 24: train_loss = 4.494892166137696
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'white', 'and', 'a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.510258197784424
# ..............................................................................................
# epoch 25: train_loss = 4.466558724721272
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'and', 'white', 'dog', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.2388811111450195
# ..............................................................................................
# epoch 26: train_loss = 4.443745504379272
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'and', 'white', 'dog', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.34016227722168
# ..............................................................................................
# epoch 27: train_loss = 4.361547685623169
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.192101001739502
# ..............................................................................................
# epoch 28: train_loss = 4.422773376464844
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.569127559661865
# ..............................................................................................
# epoch 29: train_loss = 4.305320445378621
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.472410202026367
# ..............................................................................................
# epoch 30: train_loss = 4.326834726969401
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'red', 'shirt', 'in', 'a', 'red', 'red', 'red', 'shirt', 'in', 'a', 'red', 'red', 'red', 'red', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.1883955001831055
# ..............................................................................................
# epoch 31: train_loss = 4.4093955008188885
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'and', 'a', 'man', 'in', 'a', 'red', 'red', 'and', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'and', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.506428241729736
# ..............................................................................................
# epoch 32: train_loss = 4.324974401473999
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'and', 'a', 'man', 'in', 'a', 'red', 'red', 'and', 'a', 'red', 'red', 'UNKNOWN', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.345724105834961
# ..............................................................................................
# epoch 33: train_loss = 4.346352884928385
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'and', 'a', 'red', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'and', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.186113357543945
# ..............................................................................................
# epoch 34: train_loss = 4.254444734573364
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.323157787322998
# ..............................................................................................
# epoch 35: train_loss = 4.310450199127197
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.328397750854492
# ..............................................................................................
# epoch 36: train_loss = 4.3058072916666665
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'ball', 'in', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.093813419342041
# ..............................................................................................
# epoch 37: train_loss = 4.223790161132812
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.160000324249268
# ..............................................................................................
# epoch 38: train_loss = 4.248189371744791
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'ball', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.182386875152588
# ..............................................................................................
# epoch 39: train_loss = 4.260625412623088
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'player', 'in', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.439601898193359
# ..............................................................................................
# epoch 40: train_loss = 4.319602070490519
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'and', 'a', 'red', 'and', 'red', 'and', 'red', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.251117706298828
# ..............................................................................................
# epoch 41: train_loss = 4.241135254542033
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'a', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.269909858703613
# ..............................................................................................
# epoch 42: train_loss = 4.183618343353271
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'a', 'man', 'in', 'a', 'a', 'white', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'ball', 'ENDOFSEQ']
# validation_loss = 4.183991432189941
# ..............................................................................................
# epoch 43: train_loss = 4.215736503601074
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.115534782409668
# ..............................................................................................
# epoch 44: train_loss = 4.193388092041015
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'is', 'is', 'is', 'is', 'a', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'UNKNOWN', 'a', 'red', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'a', 'white', 'and', 'white', 'and', 'white', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'player', 'in', 'a', 'white', 'ball', 'ENDOFSEQ']
# validation_loss = 4.181395530700684
# ..............................................................................................
# epoch 45: train_loss = 4.159886240005493
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'ball', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.135311126708984
# ..............................................................................................
# epoch 46: train_loss = 4.148392436981201
# sample_0_words = ['a', 'man', 'in', 'a', 'blue', 'shirt', 'in', 'a', 'blue', 'shirt', 'in', 'a', 'blue', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'a', 'white', 'white', 'and', 'a', 'white', 'white', 'and', 'a', 'white', 'white', 'ENDOFSEQ']
# validation_loss = 4.23284912109375
# ..............................................................................................
# epoch 47: train_loss = 4.189229585647583
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'a', 'red', 'and', 'a', 'man', 'in', 'a', 'a', 'red', 'shirt', 'in', 'a', 'a', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'player', 'in', 'a', 'white', 'ball', 'ENDOFSEQ']
# validation_loss = 4.191410064697266
# ..............................................................................................
# epoch 48: train_loss = 4.116867030461629
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'ball', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9970686435699463
# ..............................................................................................
# epoch 49: train_loss = 4.172867869695028
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.21921968460083
# ..............................................................................................
# epoch 50: train_loss = 4.000495368321737
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'is', 'is', 'is', 'a', 'red', 'and', 'white', 'and', 'a', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'white', 'and', 'red']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.086821556091309
# ..............................................................................................
# epoch 51: train_loss = 4.039395356178284
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'a', 'red', 'shirt', 'is', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'white', 'and', 'white', 'dog', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.1512556076049805
# ..............................................................................................
# epoch 52: train_loss = 4.10978382174174
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.291449546813965
# ..............................................................................................
# epoch 53: train_loss = 4.133698394139608
# sample_0_words = ['a', 'man', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.122579097747803
# ..............................................................................................
# epoch 54: train_loss = 4.124282730738322
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9896669387817383
# ..............................................................................................
# epoch 55: train_loss = 4.109294829686482
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.092153549194336
# ..............................................................................................
# epoch 56: train_loss = 4.088341307640076
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.134966850280762
# ..............................................................................................
# epoch 57: train_loss = 4.070955251057943
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9176442623138428
# ..............................................................................................
# epoch 58: train_loss = 4.081095120747884
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'player', 'in', 'a', 'white', 'ball', 'in', 'a', 'red', 'ball', 'ENDOFSEQ']
# validation_loss = 4.026618003845215
# ..............................................................................................
# epoch 59: train_loss = 4.078022578875224
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.801241159439087
# ..............................................................................................
# epoch 60: train_loss = 4.034120264053345
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'a', 'red', 'shirt', 'is', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.143013000488281
# ..............................................................................................
# epoch 61: train_loss = 4.03537086613973
# sample_0_words = ['a', 'man', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.003029823303223
# ..............................................................................................
# epoch 62: train_loss = 4.092444681167603
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.908538341522217
# ..............................................................................................
# epoch 63: train_loss = 4.050853815396627
# sample_0_words = ['a', 'man', 'is', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.155487537384033
# ..............................................................................................
# epoch 64: train_loss = 4.00151269086202
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.7827954292297363
# ..............................................................................................
# epoch 65: train_loss = 3.9821652170817057
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8366477489471436
# ..............................................................................................
# epoch 66: train_loss = 4.071132996241252
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9922444820404053
# ..............................................................................................
# epoch 67: train_loss = 3.956729019800822
# sample_0_words = ['a', 'man', 'is', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.95924711227417
# ..............................................................................................
# epoch 68: train_loss = 3.9280395046869914
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.823284387588501
# ..............................................................................................
# epoch 69: train_loss = 3.915179044723511
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'ball', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8717784881591797
# ..............................................................................................
# epoch 70: train_loss = 3.907727766036987
# sample_0_words = ['a', 'boy', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8634748458862305
# ..............................................................................................
# epoch 71: train_loss = 3.928214941342672
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.040843963623047
# ..............................................................................................
# epoch 72: train_loss = 3.8672979338963827
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9852664470672607
# ..............................................................................................
# epoch 73: train_loss = 4.018827477773031
# sample_0_words = ['a', 'boy', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9833569526672363
# ..............................................................................................
# epoch 74: train_loss = 3.950076459248861
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.88226580619812
# ..............................................................................................
# epoch 75: train_loss = 3.8969927285512287
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.709059715270996
# ..............................................................................................
# epoch 76: train_loss = 3.9183709716796873
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.923987865447998
# ..............................................................................................
# epoch 77: train_loss = 3.881996076901754
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.977742910385132
# ..............................................................................................
# epoch 78: train_loss = 3.87482742468516
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.720259428024292
# ..............................................................................................
# epoch 79: train_loss = 3.913169012705485
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'is', 'in', 'the', 'air', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.025177001953125
# ..............................................................................................
# epoch 80: train_loss = 3.8189544490178426
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'grass', 'ENDOFSEQ']
# validation_loss = 4.023453235626221
# ..............................................................................................
# epoch 81: train_loss = 3.8486044359207154
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'grass', 'ENDOFSEQ']
# validation_loss = 3.788173198699951
# ..............................................................................................
# epoch 82: train_loss = 3.896981772104899
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8576254844665527
# ..............................................................................................
# epoch 83: train_loss = 3.839140215555827
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.7501659393310547
# ..............................................................................................
# epoch 84: train_loss = 3.8323654476801554
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.682011127471924
# ..............................................................................................
# epoch 85: train_loss = 3.832799146970113
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.111096382141113
# ..............................................................................................
# epoch 86: train_loss = 3.8038053448994953
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9368934631347656
# ..............................................................................................
# epoch 87: train_loss = 3.786521627108256
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.02216100692749
# ..............................................................................................
# epoch 88: train_loss = 3.8446363468170164
# sample_0_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.8496499061584473
# ..............................................................................................
# epoch 89: train_loss = 3.7781849034627277
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.7265615463256836
# ..............................................................................................
# epoch 90: train_loss = 3.7924821427663167
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.672471523284912
# ..............................................................................................
# epoch 91: train_loss = 3.8789935604731243
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.7911603450775146
# ..............................................................................................
# epoch 92: train_loss = 3.868319045384725
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.7323944568634033
# ..............................................................................................
# epoch 93: train_loss = 3.761798681894938
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.962690830230713
# ..............................................................................................
# epoch 94: train_loss = 3.7666988639831542
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.9727890491485596
# ..............................................................................................
# epoch 95: train_loss = 3.805978788693746
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.787508964538574
# ..............................................................................................
# epoch 96: train_loss = 3.780985453605652
# sample_0_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'player', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.7661473751068115
# ..............................................................................................
# epoch 97: train_loss = 3.8043045241038005
# sample_0_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.866159677505493
# ..............................................................................................
# epoch 98: train_loss = 3.863606953303019
# sample_0_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.76456356048584
# ..............................................................................................
# epoch 99: train_loss = 3.6698666206995645
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.835984945297241
# ..............................................................................................
# epoch 100: train_loss = 3.8304782622655233
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8167319297790527
# ..............................................................................................
# epoch 101: train_loss = 3.7436237465540567
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.69374418258667
# ..............................................................................................
# epoch 102: train_loss = 3.7141766894658406
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.843026876449585
# ..............................................................................................
# epoch 103: train_loss = 3.7610014406840007
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.681739330291748
# ..............................................................................................
# epoch 104: train_loss = 3.7879307638804116
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8942205905914307
# ..............................................................................................
# epoch 105: train_loss = 3.7796349261601767
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.8023123741149902
# ..............................................................................................
# epoch 106: train_loss = 3.7284570213953656
# sample_0_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.6892306804656982
# ..............................................................................................
# epoch 107: train_loss = 3.732924860954285
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.7734436988830566
# ..............................................................................................
# epoch 108: train_loss = 3.7552222442626952
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.788849353790283
# ..............................................................................................
# epoch 109: train_loss = 3.702096534729004
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.71431303024292
# ..............................................................................................
# epoch 110: train_loss = 3.7572705163955686
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 4.071625709533691
# ..............................................................................................
# epoch 111: train_loss = 3.7222292369206746
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.76118803024292
# ..............................................................................................
# epoch 112: train_loss = 3.7144248237609863
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.8165647983551025
# ..............................................................................................
# epoch 113: train_loss = 3.6875748408635456
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.8770291805267334
# ..............................................................................................
# epoch 114: train_loss = 3.6712183748881024
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.4899816513061523
# ..............................................................................................
# epoch 115: train_loss = 3.7173011255264283
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.689591884613037
# ..............................................................................................
# epoch 116: train_loss = 3.8003738803863527
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.724745512008667
# ..............................................................................................
# epoch 117: train_loss = 3.7589056107203165
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.7855019569396973
# ..............................................................................................
# epoch 118: train_loss = 3.7431189057032266
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.577331304550171
# ..............................................................................................
# epoch 119: train_loss = 3.709590776761373
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.758467435836792
# ..............................................................................................
# epoch 120: train_loss = 3.753911266962687
# sample_0_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.710056781768799
# ..............................................................................................
# epoch 121: train_loss = 3.635613450050354
# sample_0_words = ['a', 'boy', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.018030643463135
# ..............................................................................................
# epoch 122: train_loss = 3.687340679168701
# sample_0_words = ['a', 'boy', 'is', 'playing', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.6273105144500732
# ..............................................................................................
# epoch 123: train_loss = 3.6452876183191933
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.794473648071289
# ..............................................................................................
# epoch 124: train_loss = 3.594419213930766
# ...
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.2993979454040527
# ..............................................................................................
# epoch 461: train_loss = 3.124450014750163
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'on', 'a', 'sidewalk', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.4035775661468506
# ..............................................................................................
# epoch 462: train_loss = 3.14554634698232
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.4039807319641113
# ..............................................................................................
# epoch 463: train_loss = 3.093629950205485
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'on', 'a', 'sidewalk', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.302762269973755
# ..............................................................................................
# epoch 464: train_loss = 3.1734619086583455
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.495234489440918
# ..............................................................................................
# epoch 465: train_loss = 3.1598244387308756
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'sidewalk', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.4236419200897217
# ..............................................................................................
# epoch 466: train_loss = 3.1533109413782756
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.2792482376098633
# ..............................................................................................
# epoch 467: train_loss = 3.1498537680308023
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'with', 'a', 'baseball', 'game', 'ENDOFSEQ']
# validation_loss = 3.315640687942505
# ..............................................................................................
# epoch 468: train_loss = 3.1320216449101768
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3876988887786865
# ..............................................................................................
# epoch 469: train_loss = 3.0927496395111085
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.417595148086548
# ..............................................................................................
# epoch 470: train_loss = 3.118437149365743
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'field', 'ENDOFSEQ']
# validation_loss = 3.24570894241333
# ..............................................................................................
# epoch 471: train_loss = 3.088625712076823
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'on', 'a', 'sidewalk', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.309994697570801
# ..............................................................................................
# epoch 472: train_loss = 3.1008209533691407
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.5291104316711426
# ..............................................................................................
# epoch 473: train_loss = 3.059781168937683
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'field', 'ENDOFSEQ']
# validation_loss = 3.208066463470459
# ..............................................................................................
# epoch 474: train_loss = 3.0809866978327434
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3677566051483154
# ..............................................................................................
# epoch 475: train_loss = 3.038538869857788
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3203375339508057
# ..............................................................................................
# epoch 476: train_loss = 3.162874556859334
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'field', 'ENDOFSEQ']
# validation_loss = 3.324968099594116
# ..............................................................................................
# epoch 477: train_loss = 3.159080171585083
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.466156005859375
# ..............................................................................................
# epoch 478: train_loss = 3.156577221552531
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.385772466659546
# ..............................................................................................
# epoch 479: train_loss = 3.1199041299819945
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3510913848876953
# ..............................................................................................
# epoch 480: train_loss = 3.057983726501465
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'with', 'a', 'baseball', 'game', 'ENDOFSEQ']
# validation_loss = 3.136726140975952
# ..............................................................................................
# epoch 481: train_loss = 3.085596027692159
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'with', 'a', 'baseball', 'game', 'ENDOFSEQ']
# validation_loss = 3.1402945518493652
# ..............................................................................................
# epoch 482: train_loss = 3.1316162824630736
# sample_0_words = ['a', 'man', 'is', 'sitting', 'on', 'a', 'skateboard', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3549611568450928
# ..............................................................................................
# epoch 483: train_loss = 3.143154619216919
# sample_0_words = ['a', 'man', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.407521963119507
# ..............................................................................................
# epoch 484: train_loss = 3.100532990773519
# sample_0_words = ['a', 'man', 'is', 'sitting', 'on', 'a', 'skateboard', 'on', 'a', 'sidewalk', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3528363704681396
# ..............................................................................................
# epoch 485: train_loss = 3.1247172085444133
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.23641037940979
# ..............................................................................................
# epoch 486: train_loss = 3.0384028164545693
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'field', 'ENDOFSEQ']
# validation_loss = 3.452117919921875
# ..............................................................................................
# epoch 487: train_loss = 3.099561637242635
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.2151379585266113
# ..............................................................................................
# epoch 488: train_loss = 3.117613522529602
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.157050848007202
# ..............................................................................................
# epoch 489: train_loss = 3.0833993012110392
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'a', 'game', 'ENDOFSEQ']
# validation_loss = 3.3503785133361816
# ..............................................................................................
# epoch 490: train_loss = 3.1126118777592975
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'with', 'a', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.338029146194458
# ..............................................................................................
# epoch 491: train_loss = 3.087394560813904
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3031632900238037
# ..............................................................................................
# epoch 492: train_loss = 3.092113330523173
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.55005145072937
# ..............................................................................................
# epoch 493: train_loss = 3.124046065648397
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.367440700531006
# ..............................................................................................
# epoch 494: train_loss = 3.0596349312464395
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'a', 'game', 'ENDOFSEQ']
# validation_loss = 3.370671272277832
# ..............................................................................................
# epoch 495: train_loss = 3.107672864596049
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.414827823638916
# ..............................................................................................
# epoch 496: train_loss = 3.0578055753707885
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3684003353118896
# ..............................................................................................
# epoch 497: train_loss = 3.125818007151286
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'field', 'ENDOFSEQ']
# validation_loss = 3.292790412902832
# ..............................................................................................
# epoch 498: train_loss = 3.114738130569458
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'field', 'ENDOFSEQ']
# validation_loss = 3.4343907833099365
# ..............................................................................................
# epoch 499: train_loss = 3.1129021078745525
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.3079466819763184
# ..............................................................................................
# epoch 500: train_loss = 3.1247246487935385
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'jumping', 'on', 'a', 'skateboard', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'playing', 'in', 'the', 'air', 'ENDOFSEQ']
# validation_loss = 3.2479588985443115

# %%
test_images_filepath = 'flickr/Flickr_Data/Flickr_TextData/Flickr_8k.testImages.txt'
with open(test_images_filepath, 'r') as test_images_file:
    test_images_list = [line.strip() for line in test_images_file]
print("lowest validation loss = {}".format(lowestValidationLoss))    
print ("len(test_images_list) = {}".format(len(test_images_list)))
# Out:
# lowest validation loss = 3.1281590461730957
# len(test_images_list) = 1000

# %%
# Load the model that gave the lowest validation loss
lstm_model.load_state_dict(torch.load(best_model_filepath))
# Randomly select some test images
test_image_sample_indices = random.choices(range(len(test_images_list)), k=3)
lstm_model.eval()
test_sample_filepaths = []
test_sample_captions = []
for test_image_sample_index in test_image_sample_indices:
    sample_words = TestSample(test_image_sample_index, test_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
    caption = ' '.join(sample_words)
    test_sample_filepaths.append(os.path.join(imagesFilepath, test_images_list[test_image_sample_index]))
    test_sample_captions.append(caption)

# %%
print (test_sample_captions[0])
IPython.display.Image(test_sample_filepaths[0])
# Out:
# a black dog is running through the snow ENDOFSEQ

# %%
import nltk
import csv
from nltk.translate.bleu_score import sentence_bleu
from collections import defaultdict


# Load tokenized descriptions
tokenized_descriptions = defaultdict(list)
with open(pretokenized_descriptions_filepath, 'r') as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    for row in reader:
        image_name = row[0]
        caption_indices = []
        for index_str in row[1:]:
            index = int(index_str)
            if index == 2:
                break  # Stop capturing indices when index is 2
            caption_indices.append(index)
        tokenized_descriptions[image_name].append(caption_indices)

# %%
# Function to convert indices to words
def indices_to_words(indices):
    return [index_to_word_dict[index] for index in indices]

# Calculate BLEU score for each test image
total_bleu_score_1 = 0
total_bleu_score_2 = 0
total_bleu_score_3 = 0
total_bleu_score_4 = 0
total_images = len(test_images_list)
lstm_model.eval()
test_image_sample_indices_all = len(test_images_list);

for index in  range(test_image_sample_indices_all):
     sample_words = TestSample(index, test_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
     description = ' '.join(sample_words)
     candidate_caption = Tokenize(description, nlp)

     reference_captions = [indices_to_words(indices) for indices in tokenized_descriptions[test_images_list[index]]]

     bleu_score_1 = sentence_bleu(reference_captions, candidate_caption, weights=(1, 0, 0, 0))
     bleu_score_2 = sentence_bleu(reference_captions, candidate_caption, weights=(0.5, 0.5, 0, 0))
     bleu_score_3 = sentence_bleu(reference_captions, candidate_caption, weights=(0.33, 0.33, 0.33, 0))
     bleu_score_4 = sentence_bleu(reference_captions, candidate_caption, weights=(0.25, 0.25, 0.25, 0.25))
    
     total_bleu_score_1 += bleu_score_1
     total_bleu_score_2 += bleu_score_2
     total_bleu_score_3 += bleu_score_3
     total_bleu_score_4 += bleu_score_4

average_bleu_score_1 = total_bleu_score_1 / total_images
average_bleu_score_2 = total_bleu_score_2 / total_images
average_bleu_score_3 = total_bleu_score_3 / total_images
average_bleu_score_4 = total_bleu_score_4 / total_images

# average_bleu_score = total_bleu_score / len(test_images)
print("Average BLEU-1 score:", average_bleu_score_1)
print("Average BLEU-2 score:", average_bleu_score_2)
print("Average BLEU-3 score:", average_bleu_score_3)
print("Average BLEU-4 score:", average_bleu_score_4)
# Out:
# Average BLEU-1 score: 0.5202970280329978
# Average BLEU-2 score: 0.3236744954911404
# Average BLEU-3 score: 0.1341793193712665
# Average BLEU-4 score: 0.050970741654506005
