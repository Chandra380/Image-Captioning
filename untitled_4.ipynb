# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import torch
import torchvision
from PIL import Image
import IPython.display

# %%
imagesFilepath = "flickr\Flickr_Data\Images"
number_of_latent_variables = 2048

# %%
# Create a list of jpg image filepaths
found_jpg_filepaths = []
directory_contents = os.listdir(imagesFilepath)
for content in directory_contents:
    filepath = os.path.join(imagesFilepath, content)
    if filepath.endswith('.jpg'):
        found_jpg_filepaths.append(filepath)
print(found_jpg_filepaths[0])
# Out:
# flickr\Flickr_Data\Images\1000268201_693b08cb0e.jpg

# %%
training_images_filepath = "flickr\Flickr_Data\Flickr_TextData\Flickr_8k.trainImages.txt"
validation_images_filepath = "flickr\Flickr_Data\Flickr_TextData\Flickr_8k.devImages.txt"
pretokenized_descriptions_filepath = "tokenized_descriptions_flickr.csv"
vocabulary_filepath = 'vocabulary_flickr.csv'
words2vec_dictionary_filepath = 'words2vec/flickr_words2vec.csv'
latent_representation_filepath = 'flickr_latent_resNet.csv'

latent_representationDf = pd.read_csv(latent_representation_filepath)
tokenized_descriptionsDf = pd.read_csv(pretokenized_descriptions_filepath)

# %%
with open(training_images_filepath, 'r') as train_images_file:
    train_images_list = [line.strip() for line in train_images_file]

# %%
def LoadVocabulary(vocabularyFilepath):
    word_to_index_dict = {}
    index_to_word_dict = {}
    vocabDf = pd.read_csv(vocabularyFilepath)
    for i, row in vocabDf.iterrows():
        index = row['index']
        word = row['word']
        word_to_index_dict[word] = index
        index_to_word_dict[index] = word
    return word_to_index_dict, index_to_word_dict

word_to_index_dict, index_to_word_dict = LoadVocabulary(vocabulary_filepath)

# %%
word2vecDf = pd.read_csv(words2vec_dictionary_filepath)
embedding_dimension = 128
word_to_embedding_dict = {word2vecDf.iloc[i]['word'] : word2vecDf.loc[i, 'e0': 'e{}'.format(embedding_dimension - 1)].tolist()
                              for i in range(len(word2vecDf))}

# %%
import en_core_web_sm
import re
import string

nlp = en_core_web_sm.load()

def Tokenize(text, nlp):
    text = re.sub(r"[^\x00-\x7F]+", " ", text)
    regex = re.compile('[' + re.escape(string.punctuation) + '0-9\\r\\t\\n]')  # Remove punctuation and numbers
    nopunct = regex.sub(" ", text.lower())
    tokens = [token.text for token in nlp.tokenizer(nopunct) if not token.text.isspace()]
    return tokens

# %%
from torch.utils.data import Dataset, DataLoader
import random

class CaptionGenerationDataset(Dataset):
    def __init__(self,
                 image_filenames,
                 image_filename_to_latent_variables,
                 image_filename_to_tokenized_descriptions_list,
                 endOfSeqIndex,
                 notSetIndex,
                 vocabulary_size,
                 index_to_word_dict,
                 word_to_embedding_dict
                 ):
        self.image_filenames = image_filenames
        self.image_filename_to_latent_variables = image_filename_to_latent_variables
        self.image_filename_to_tokenized_descriptions_list = image_filename_to_tokenized_descriptions_list
        self.endOfSeqIndex = endOfSeqIndex
        self.notSetIndex = notSetIndex
        self.vocabulary_size = vocabulary_size
        self.index_to_word_dict = index_to_word_dict
        self.word_to_embedding_dict = word_to_embedding_dict

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        if idx >= len(self.image_filenames):
            raise IndexError("CaptionGenerationDataset.__getitem__(): Index {} is greater than the number of images ({})".format(idx, len(self.image_filenames)))
        filename = self.image_filenames[idx]
        latent_variables = self.image_filename_to_latent_variables[filename]
        # Build a tensor
        latent_variablesTsr = torch.zeros(len(latent_variables))
        for i in range(len(latent_variables)):
            latent_variablesTsr[i] = latent_variables[i]
        # Randomly choose one of the descriptions
        description = random.choice(self.image_filename_to_tokenized_descriptions_list[filename])
        lastIndex = self.IndexOfEndOfSeq(description)
        chopIndex = random.randint(0, lastIndex) - 1 # The last index of the chopped description
        choppedDescription = [self.notSetIndex] * len(description)
        if chopIndex >= 0:
            for i in range(chopIndex + 1):
                choppedDescription[i] = description[i]

        embedding_dim = len(self.word_to_embedding_dict[ self.index_to_word_dict[0] ]) # Length of the embedding of the 1st word
        embeddedChoppedDescriptionTsr = torch.zeros((len(description), embedding_dim))
        for wordPosn in range(len(choppedDescription)):
            embedding = self.word_to_embedding_dict[ self.index_to_word_dict[choppedDescription[wordPosn]]]
            embeddedChoppedDescriptionTsr[wordPosn] = torch.tensor(embedding)

        next_word_index = description[chopIndex + 1]

        return ( (latent_variablesTsr, embeddedChoppedDescriptionTsr), next_word_index)

    def IndexOfEndOfSeq(self, description_list):
        foundIndex = -1
        for candidateNdx in range(len(description_list)):
            if description_list[candidateNdx] == self.endOfSeqIndex:
                foundIndex = candidateNdx
                break
        if foundIndex == -1:
            return len(description_list) - 1
        else:
            return foundIndex
        
def ImageFilenameToLatentVariables(latent_varDf):
    image_filename_to_latent_variables = {}
    for i, row in latent_varDf.iterrows():
        filepath = latent_varDf.iloc[i][0]
        filename = os.path.basename(filepath)
        latent_variables = list(latent_varDf.iloc[i][1:])
        image_filename_to_latent_variables[filename] = latent_variables
    return image_filename_to_latent_variables

image_filename_to_latent_variables = ImageFilenameToLatentVariables(latent_representationDf)

def ImageFilenameToTokenizedDescriptionsList(descriptionsDF):
    image_filename_to_tokenized_description = {}
    for i, row in descriptionsDF.iterrows():
        filename = descriptionsDF.iloc[i][0]
        tokenized_description = list(descriptionsDF.iloc[i][1:])
        if filename in image_filename_to_tokenized_description:
            image_filename_to_tokenized_description[filename].append(tokenized_description)
        else:
            image_filename_to_tokenized_description[filename] = [tokenized_description]
    return image_filename_to_tokenized_description

image_filename_to_tokenized_descriptions_list = ImageFilenameToTokenizedDescriptionsList(tokenized_descriptionsDf)

lstm_train_dataset = CaptionGenerationDataset(
        train_images_list,
        image_filename_to_latent_variables,
        image_filename_to_tokenized_descriptions_list,
        word_to_index_dict['ENDOFSEQ'],
        word_to_index_dict['NOTSET'],
        len(word_to_index_dict),
        index_to_word_dict,
        word_to_embedding_dict
    )

# %%
with open(validation_images_filepath, 'r') as valid_images_file:
    validation_images_list = [line.strip() for line in valid_images_file]
lstm_validation_dataset = CaptionGenerationDataset(
        validation_images_list,
        image_filename_to_latent_variables,
        image_filename_to_tokenized_descriptions_list,
        word_to_index_dict['ENDOFSEQ'],
        word_to_index_dict['NOTSET'],
        len(word_to_index_dict),
        index_to_word_dict,
        word_to_embedding_dict
    )

# %%
useCuda = torch.cuda.is_available()

# %%
class LSTM_fixed_embedding(torch.nn.Module):
    def __init__(self, embedding_dim, lstm_hidden_dim,
                 num_lstm_layers, image_latent_dim,
                 vocab_size,
                 dropoutProportion=0.6):
        super(LSTM_fixed_embedding, self).__init__()
        self.embedding_dim = embedding_dim
        self.lstm = torch.nn.LSTM(embedding_dim, lstm_hidden_dim, num_lstm_layers,
                                  batch_first=True)
        self.dropout = torch.nn.Dropout(dropoutProportion)
        self.linear = torch.nn.Linear(lstm_hidden_dim + image_latent_dim, vocab_size)


    def forward(self, image_latentTsr, embeddedChoppedDescriptionTsr):
        # image_latentTsr.shape = (N, image_latent_dim)
        # embeddedChoppedDescriptionTsr.shape = (N, sequence_length, embedding_dim)
        aggregated_h, (ht, ct) = self.lstm(embeddedChoppedDescriptionTsr)
        # ht.shape = (num_lstm_layers, N, lstm_hidden_dim)
        # ht[-1].shape = (N, lstm_hidden_dim)
        concat_latent = torch.cat( (torch.nn.functional.normalize(ht[-1]),
                                    torch.nn.functional.normalize(image_latentTsr)), dim=1)
        # concat_latent.shape = (N, image_latent_dim + lstm_hidden_dim)
        outputTsr = self.linear(self.dropout(concat_latent))
        # outputTsr.shape = (N, vocab_size)
        return outputTsr

    def Caption(self, latentVariablesTsr, maximumLength,
                         word_to_embedding_dict, index_to_word_dict,
                         endOfSeqIndex, useCuda):
        notSetEmbedding = word_to_embedding_dict['NOTSET']
        embeddedChoppedDescriptionTsr = torch.zeros((maximumLength, self.embedding_dim))
        for i in range(maximumLength):
            embeddedChoppedDescriptionTsr[i] = torch.tensor(notSetEmbedding)
        endOfSeqIsFound = False
        runningNdx = 0
        caption_words = []
        while not endOfSeqIsFound and runningNdx < maximumLength:
            if useCuda:
                latentVariablesTsr = latentVariablesTsr.cuda()
                embeddedChoppedDescriptionTsr = embeddedChoppedDescriptionTsr.cuda()
            outputTsr = self.forward(latentVariablesTsr.unsqueeze(0), embeddedChoppedDescriptionTsr.unsqueeze(0))
            next_word_index = torch.argmax(outputTsr[0]).item()
            caption_words.append(index_to_word_dict[next_word_index])
            next_word = index_to_word_dict[next_word_index]
            embeddedChoppedDescriptionTsr[runningNdx] = torch.tensor(word_to_embedding_dict[next_word])
            runningNdx += 1
            if next_word_index == endOfSeqIndex:
                endOfSeqIsFound = True
        return caption_words

lstm_hidden_dimension = 64
lstm_number_of_layers = 3
dropoutProportion = 0.6
lstm_model = LSTM_fixed_embedding(
        embedding_dim=embedding_dimension,
        lstm_hidden_dim=lstm_hidden_dimension,
        num_lstm_layers=lstm_number_of_layers,
        image_latent_dim=number_of_latent_variables,
        vocab_size=len(word_to_index_dict),
        dropoutProportion=dropoutProportion
    )

if useCuda:
    lstm_model = lstm_model.cuda()

# %%
def TestSample(index, validation_images_list, image_filename_to_latent_variables, model,
               index_to_word_dict,
               word_to_embedding_dict,
               sequence_length=40,
               endOfSeqIndex=0,
               useCuda=True):
    sample_filename = validation_images_list[index]
    sample_latentVariablesTsr = torch.FloatTensor(image_filename_to_latent_variables[sample_filename])
    if useCuda:
        sample_latentVariablesTsr = sample_latentVariablesTsr.cuda()
    sample_words = model.Caption(
        latentVariablesTsr=sample_latentVariablesTsr,
        maximumLength=sequence_length,
        word_to_embedding_dict=word_to_embedding_dict,
        index_to_word_dict=index_to_word_dict,
        endOfSeqIndex=endOfSeqIndex,
        useCuda=useCuda
    )
    return sample_words

validation_sample_0_Ndx = 0
validation_sample_100_Ndx = 100
IPython.display.Image(os.path.join(imagesFilepath, validation_images_list[validation_sample_0_Ndx]))

# %%
best_model_filepath = 'lstm_rNet_flickr.pth'

# %%
import sys

parameters = filter(lambda p: p.requires_grad, lstm_model.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.0003)
lossFcn = torch.nn.CrossEntropyLoss()
train_dataLoader = DataLoader(lstm_train_dataset, batch_size=16, shuffle=True)
validation_dataLoader = DataLoader(lstm_validation_dataset, batch_size=lstm_validation_dataset.__len__())

lowestValidationLoss = sys.float_info.max

for epoch in range(1, 500 + 1):
    lstm_model.train()
    loss_sum = 0.0
    numberOfBatches = 0
    for ( (latent_variablesTsr, chopped_descriptionTsr), target_next_word) in train_dataLoader:
        if numberOfBatches % 4 == 1:
            print (".", end="", flush=True)
        if useCuda:
            latent_variablesTsr = latent_variablesTsr.cuda()
            chopped_descriptionTsr = chopped_descriptionTsr.cuda()
            target_next_word = target_next_word.cuda()
        predicted_next_word = lstm_model(latent_variablesTsr, chopped_descriptionTsr)
#         print(predicted_next_word)
        optimizer.zero_grad()
        loss = lossFcn(predicted_next_word, target_next_word)
        loss.backward()
        optimizer.step()
        loss_sum += loss.item()
        numberOfBatches += 1
    train_loss = loss_sum/numberOfBatches
    print ("\nepoch {}: train_loss = {}".format(epoch, train_loss))

    # Validation
    lstm_model.eval()
    sample_0_words = TestSample(validation_sample_0_Ndx, validation_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
    print ("sample_0_words = {}".format(sample_0_words))
    sample_100_words = TestSample(validation_sample_100_Ndx, validation_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
    print ("sample_100_words = {}".format(sample_100_words))
    
    for ((validation_latent_variablesTsr, validation_chopped_descriptionTsr), validation_target_next_word) in validation_dataLoader:
        if useCuda:
            validation_latent_variablesTsr = validation_latent_variablesTsr.cuda()
            validation_chopped_descriptionTsr = validation_chopped_descriptionTsr.cuda()
            validation_target_next_word = validation_target_next_word.cuda()
        validation_predicted_next_word = lstm_model(validation_latent_variablesTsr, validation_chopped_descriptionTsr)
        validation_loss = lossFcn(validation_predicted_next_word, validation_target_next_word).item()
    print ("validation_loss = {}".format(validation_loss))

    if validation_loss < lowestValidationLoss:
        lowestValidationLoss = validation_loss
        torch.save(lstm_model.state_dict(), best_model_filepath)
# Out:
# ..............................................................................................
# epoch 1: train_loss = 6.8018778177897135
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.581594467163086
# ..............................................................................................
# epoch 2: train_loss = 5.467130573908488
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.360019207000732
# ..............................................................................................
# epoch 3: train_loss = 5.386938916524251
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.285147666931152
# ..............................................................................................
# epoch 4: train_loss = 5.33617120107015
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.3338942527771
# ..............................................................................................
# epoch 5: train_loss = 5.34232369740804
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.384449005126953
# ..............................................................................................
# epoch 6: train_loss = 5.255229233423869
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.12706184387207
# ..............................................................................................
# epoch 7: train_loss = 5.213485768000285
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.073885917663574
# ..............................................................................................
# epoch 8: train_loss = 5.105901696523031
# sample_0_words = ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'ENDOFSEQ']
# validation_loss = 5.124059677124023
# ..............................................................................................
# epoch 9: train_loss = 5.155951955795288
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'ENDOFSEQ']
# validation_loss = 5.165398597717285
# ..............................................................................................
# epoch 10: train_loss = 5.124360498428345
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'ENDOFSEQ']
# validation_loss = 5.070196151733398
# ..............................................................................................
# epoch 11: train_loss = 5.151716852823893
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'ENDOFSEQ']
# validation_loss = 4.865936756134033
# ..............................................................................................
# epoch 12: train_loss = 5.126950226465861
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# validation_loss = 5.156564235687256
# ..............................................................................................
# epoch 13: train_loss = 5.027089677174886
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.910824298858643
# ..............................................................................................
# epoch 14: train_loss = 5.064427536010742
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'ENDOFSEQ']
# validation_loss = 5.001860618591309
# ..............................................................................................
# epoch 15: train_loss = 5.120174101511638
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'ENDOFSEQ']
# validation_loss = 5.1501007080078125
# ..............................................................................................
# epoch 16: train_loss = 5.017317466100057
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'ENDOFSEQ']
# validation_loss = 4.724310398101807
# ..............................................................................................
# epoch 17: train_loss = 5.025519522984823
# sample_0_words = ['a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'ENDOFSEQ']
# validation_loss = 4.8563055992126465
# ..............................................................................................
# epoch 18: train_loss = 4.974319451649984
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.970007419586182
# ..............................................................................................
# epoch 19: train_loss = 4.8991703592936195
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'ENDOFSEQ']
# validation_loss = 4.8709330558776855
# ..............................................................................................
# epoch 20: train_loss = 4.959888608296712
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'ENDOFSEQ']
# validation_loss = 4.766303062438965
# ..............................................................................................
# epoch 21: train_loss = 4.838305210113526
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.695685863494873
# ..............................................................................................
# epoch 22: train_loss = 4.847974667867025
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.668998718261719
# ..............................................................................................
# epoch 23: train_loss = 4.816713603973389
# sample_0_words = ['a', 'in', 'on', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.822268486022949
# ..............................................................................................
# epoch 24: train_loss = 4.79406281153361
# sample_0_words = ['a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'ENDOFSEQ']
# validation_loss = 4.715492248535156
# ..............................................................................................
# epoch 25: train_loss = 4.7517723445892335
# sample_0_words = ['a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.826180458068848
# ..............................................................................................
# epoch 26: train_loss = 4.752533303578694
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.808210849761963
# ..............................................................................................
# epoch 27: train_loss = 4.7169766438802085
# sample_0_words = ['a', 'man', 'man', 'in', 'a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'man', 'in', 'a', 'in', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.8733038902282715
# ..............................................................................................
# epoch 28: train_loss = 4.723426923751831
# sample_0_words = ['a', 'in', 'a', 'in', 'a', 'in', 'a', 'on', 'a', 'on', 'a', 'on', 'a', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'is', 'is', 'on', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.871534824371338
# ..............................................................................................
# epoch 29: train_loss = 4.8016473547617595
# sample_0_words = ['a', 'is', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'is', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.694516181945801
# ..............................................................................................
# epoch 30: train_loss = 4.687147190093994
# sample_0_words = ['a', 'is', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'is', 'is', 'is', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'is', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'is', 'is', 'is', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.749053478240967
# ..............................................................................................
# epoch 31: train_loss = 4.705727575302124
# sample_0_words = ['a', 'man', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.6003031730651855
# ..............................................................................................
# epoch 32: train_loss = 4.695947619756063
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.5478105545043945
# ..............................................................................................
# epoch 33: train_loss = 4.623211693445842
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.675778388977051
# ..............................................................................................
# epoch 34: train_loss = 4.599779143651326
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'in', 'a', 'is', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'in', 'a', 'is', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# validation_loss = 4.507827281951904
# ..............................................................................................
# epoch 35: train_loss = 4.649655343373617
# sample_0_words = ['a', 'man', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.487048625946045
# ..............................................................................................
# epoch 36: train_loss = 4.592822312672933
# sample_0_words = ['a', 'man', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.654895305633545
# ..............................................................................................
# epoch 37: train_loss = 4.535202226003011
# sample_0_words = ['a', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'on', 'a', 'in', 'on', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'is', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# validation_loss = 4.484612941741943
# ..............................................................................................
# epoch 38: train_loss = 4.556146319707235
# sample_0_words = ['a', 'man', 'in', 'a', 'a', 'is', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'on', 'a', 'in', 'on', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.5265889167785645
# ..............................................................................................
# epoch 39: train_loss = 4.584366306304932
# sample_0_words = ['a', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.374782562255859
# ..............................................................................................
# epoch 40: train_loss = 4.56901921526591
# sample_0_words = ['a', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.575984477996826
# ..............................................................................................
# epoch 41: train_loss = 4.478704334894816
# sample_0_words = ['a', 'man', 'in', 'a', 'a', 'is', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.48361873626709
# ..............................................................................................
# epoch 42: train_loss = 4.563573687871298
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.382811546325684
# ..............................................................................................
# epoch 43: train_loss = 4.458492254892985
# sample_0_words = ['a', 'man', 'in', 'a', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.26036262512207
# ..............................................................................................
# epoch 44: train_loss = 4.475094902992248
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.436037540435791
# ..............................................................................................
# epoch 45: train_loss = 4.464870455423991
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'white', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.413406848907471
# ..............................................................................................
# epoch 46: train_loss = 4.565379321416219
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'man', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.516386985778809
# ..............................................................................................
# epoch 47: train_loss = 4.356649684270223
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'is', 'is', 'is', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.414863586425781
# ..............................................................................................
# epoch 48: train_loss = 4.397730849901835
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'a', 'man', 'in', 'a', 'a', 'man', 'in', 'a', 'red', 'in', 'a', 'red', 'in', 'a', 'on', 'a', 'in', 'on', 'a', 'in', 'on', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'man', 'in', 'a', 'white', 'ball', 'ENDOFSEQ']
# validation_loss = 4.335260391235352
# ..............................................................................................
# epoch 49: train_loss = 4.344594869613648
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'man', 'in', 'a', 'red', 'is', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'white', 'man', 'is', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.287703990936279
# ..............................................................................................
# epoch 50: train_loss = 4.432667424519857
# sample_0_words = ['a', 'man', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.237260818481445
# ..............................................................................................
# epoch 51: train_loss = 4.414117741266886
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.0997090339660645
# ..............................................................................................
# epoch 52: train_loss = 4.386083108266194
# sample_0_words = ['a', 'man', 'is', 'is', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.434614181518555
# ..............................................................................................
# epoch 53: train_loss = 4.28155070845286
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'a', 'red', 'is', 'is', 'is', 'in', 'a', 'a', 'red', 'is', 'is', 'in', 'a', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'is', 'ball', 'ENDOFSEQ']
# validation_loss = 4.190420150756836
# ..............................................................................................
# epoch 54: train_loss = 4.307484445571899
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'man', 'in', 'a', 'red', 'red', 'is', 'is', 'in', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'is', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.2757792472839355
# ..............................................................................................
# epoch 55: train_loss = 4.28440973218282
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'red', 'is', 'in', 'a', 'red', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.349377632141113
# ..............................................................................................
# epoch 56: train_loss = 4.209344996770223
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'in', 'a', 'red', 'and', 'a', 'man', 'in', 'a', 'red', 'in', 'a', 'red', 'in', 'a', 'on', 'a', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.314970016479492
# ..............................................................................................
# epoch 57: train_loss = 4.220804893811544
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.271160125732422
# ..............................................................................................
# epoch 58: train_loss = 4.265586193084717
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'in', 'a', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.405219554901123
# ..............................................................................................
# epoch 59: train_loss = 4.2025745677948
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.165966510772705
# ..............................................................................................
# epoch 60: train_loss = 4.219754693984985
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.123842716217041
# ..............................................................................................
# epoch 61: train_loss = 4.297933477401734
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'is', 'player', 'is', 'player', 'is', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.031052112579346
# ..............................................................................................
# epoch 62: train_loss = 4.2355764869054155
# sample_0_words = ['a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'is', 'player', 'is', 'player', 'is', 'is', 'player', 'is', 'is', 'player', 'is', 'is', 'player', 'is', 'is', 'player', 'ENDOFSEQ']
# validation_loss = 4.290780544281006
# ..............................................................................................
# epoch 63: train_loss = 4.296044408798218
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'and', 'a', 'man', 'is', 'is', 'is', 'is', 'in', 'a', 'red', 'and', 'a', 'man', 'in', 'a', 'red', 'and', 'a', 'red', 'is', 'is', 'is', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.118919849395752
# ..............................................................................................
# epoch 64: train_loss = 4.118167129516602
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'is', 'is', 'is', 'in', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.13511848449707
# ..............................................................................................
# epoch 65: train_loss = 4.208806197484335
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.166597843170166
# ..............................................................................................
# epoch 66: train_loss = 4.159109839757283
# sample_0_words = ['a', 'man', 'is', 'is', 'on', 'a', 'red', 'and', 'a', 'man', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'is', 'player', 'is', 'player', 'is', 'player', 'is', 'player', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.05931282043457
# ..............................................................................................
# epoch 67: train_loss = 4.116715015729269
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'is', 'is', 'is', 'on', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.166164875030518
# ..............................................................................................
# epoch 68: train_loss = 4.1730544452667235
# sample_0_words = ['a', 'man', 'in', 'a', 'man', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'in', 'a', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'is', 'player', 'is', 'is', 'player', 'is', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.22548246383667
# ..............................................................................................
# epoch 69: train_loss = 4.169037954966227
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'is', 'is', 'is', 'in', 'a', 'red', 'is', 'is', 'is', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'is', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.1566057205200195
# ..............................................................................................
# epoch 70: train_loss = 4.142601655960083
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'red', 'is', 'is', 'in', 'a', 'red', 'and', 'a', 'red', 'is', 'is', 'in', 'a', 'street', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.027470111846924
# ..............................................................................................
# epoch 71: train_loss = 4.137538935343424
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.066451549530029
# ..............................................................................................
# epoch 72: train_loss = 4.121632936795552
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'is', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.240667819976807
# ..............................................................................................
# epoch 73: train_loss = 4.166750141143799
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'red', 'shirt', 'is', 'in', 'a', 'red', 'red', 'shirt', 'is', 'in', 'a', 'red', 'UNKNOWN', 'and', 'a', 'red', 'UNKNOWN', 'and', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 3.937415838241577
# ..............................................................................................
# epoch 74: train_loss = 4.054722064971924
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'and', 'a', 'red', 'and', 'a', 'red', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.029321193695068
# ..............................................................................................
# epoch 75: train_loss = 4.096660140355428
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.017280578613281
# ..............................................................................................
# epoch 76: train_loss = 4.091769454320271
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'UNKNOWN', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'is', 'player', 'in', 'a', 'ball', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.0768351554870605
# ..............................................................................................
# epoch 77: train_loss = 4.186179297765096
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.139504432678223
# ..............................................................................................
# epoch 78: train_loss = 4.038513305664062
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'in', 'a', 'player', 'is', 'player', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.956465244293213
# ..............................................................................................
# epoch 79: train_loss = 4.073944550832112
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'ball', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.062677383422852
# ..............................................................................................
# epoch 80: train_loss = 4.023311118125916
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.182889938354492
# ..............................................................................................
# epoch 81: train_loss = 4.0271751410166425
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.178318500518799
# ..............................................................................................
# epoch 82: train_loss = 4.035893404960633
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.182016372680664
# ..............................................................................................
# epoch 83: train_loss = 4.043624324798584
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 4.066466808319092
# ..............................................................................................
# epoch 84: train_loss = 4.083257233301799
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.873086452484131
# ..............................................................................................
# epoch 85: train_loss = 3.997732495625814
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'in', 'a', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 3.9349205493927
# ..............................................................................................
# epoch 86: train_loss = 4.091931526184082
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'playing', 'in', 'the', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 3.9234845638275146
# ..............................................................................................
# epoch 87: train_loss = 4.012096528371175
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.04954719543457
# ..............................................................................................
# epoch 88: train_loss = 3.9856863740285235
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 4.179356575012207
# ..............................................................................................
# epoch 89: train_loss = 4.0454335892995195
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9566562175750732
# ..............................................................................................
# epoch 90: train_loss = 4.086795857747396
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.057426929473877
# ..............................................................................................
# epoch 91: train_loss = 4.017921562830607
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'is', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'in', 'a', 'player', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.039982318878174
# ..............................................................................................
# epoch 92: train_loss = 4.031984913508097
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 3.918334484100342
# ..............................................................................................
# epoch 93: train_loss = 4.038128740628561
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'is', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'player', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.027583122253418
# ..............................................................................................
# epoch 94: train_loss = 3.9715884552001954
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'the', 'player', 'in', 'a', 'player', 'ENDOFSEQ']
# validation_loss = 3.8924551010131836
# ..............................................................................................
# epoch 95: train_loss = 3.9285872033437093
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'player', 'is', 'playing', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.059551239013672
# ..............................................................................................
# epoch 96: train_loss = 3.948799870491028
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.864856243133545
# ..............................................................................................
# epoch 97: train_loss = 4.009288491884868
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'player', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.862363576889038
# ..............................................................................................
# epoch 98: train_loss = 4.070222427368164
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'ball', 'ENDOFSEQ']
# validation_loss = 3.863874912261963
# ..............................................................................................
# epoch 99: train_loss = 4.006588393529256
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.879108190536499
# ..............................................................................................
# epoch 100: train_loss = 3.943410630544027
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.93688702583313
# ..............................................................................................
# epoch 101: train_loss = 3.9174649934768677
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'and', 'red', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9435060024261475
# ..............................................................................................
# epoch 102: train_loss = 3.926152414004008
# sample_0_words = ['a', 'man', 'is', 'on', 'a', 'red', 'shirt', 'is', 'on', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.174795627593994
# ..............................................................................................
# epoch 103: train_loss = 3.9347199255625407
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'ball', 'in', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.9807913303375244
# ..............................................................................................
# epoch 104: train_loss = 3.930229263941447
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.933262825012207
# ..............................................................................................
# epoch 105: train_loss = 3.9226042518615722
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'a', 'baseball', 'ENDOFSEQ']
# validation_loss = 4.0221052169799805
# ..............................................................................................
# epoch 106: train_loss = 3.9305264441172283
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'player', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.829885482788086
# ..............................................................................................
# epoch 107: train_loss = 3.904457563082377
# sample_0_words = ['a', 'man', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8660361766815186
# ..............................................................................................
# epoch 108: train_loss = 3.873257551511129
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'player', 'in', 'a', 'baseball', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8688461780548096
# ..............................................................................................
# epoch 109: train_loss = 3.8989084186553957
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.850522041320801
# ..............................................................................................
# epoch 110: train_loss = 3.799491530418396
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.943911552429199
# ..............................................................................................
# epoch 111: train_loss = 3.903018898010254
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 3.802405834197998
# ..............................................................................................
# epoch 112: train_loss = 3.885066037495931
# sample_0_words = ['a', 'boy', 'in', 'a', 'white', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'in', 'a', 'baseball', 'player', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# validation_loss = 4.06754207611084
# ..............................................................................................
# epoch 113: train_loss = 3.8769772151311237
# sample_0_words = ['a', 'boy', 'is', 'in', 'a', 'red', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'in', 'a', 'ball', 'ENDOFSEQ']
# validation_loss = 3.8853917121887207
# ..............................................................................................
# epoch 114: train_loss = 3.8671375935872394
# sample_0_words = ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'in', 'a', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'man', 'is', 'playing', 'on', 'the', 'ball', 'ENDOFSEQ']
# ...
# validation_loss = 3.2422611713409424
# ..............................................................................................
# epoch 459: train_loss = 3.2265651709238687
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.495501756668091
# ..............................................................................................
# epoch 460: train_loss = 3.2215749197006227
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3417584896087646
# ..............................................................................................
# epoch 461: train_loss = 3.2545457493464154
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4096851348876953
# ..............................................................................................
# epoch 462: train_loss = 3.2558944975535073
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4259355068206787
# ..............................................................................................
# epoch 463: train_loss = 3.2054730507532754
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.2478981018066406
# ..............................................................................................
# epoch 464: train_loss = 3.234466293334961
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'and', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.2617480754852295
# ..............................................................................................
# epoch 465: train_loss = 3.196608753522237
# sample_0_words = ['a', 'man', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4901983737945557
# ..............................................................................................
# epoch 466: train_loss = 3.2535015780131022
# sample_0_words = ['a', 'man', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.406547784805298
# ..............................................................................................
# epoch 467: train_loss = 3.2574800879160564
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.5445027351379395
# ..............................................................................................
# epoch 468: train_loss = 3.1309768295288087
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'in', 'a', 'baseball', 'baseball', 'baseball', 'game', 'ENDOFSEQ']
# validation_loss = 3.310206413269043
# ..............................................................................................
# epoch 469: train_loss = 3.201998318354289
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3229353427886963
# ..............................................................................................
# epoch 470: train_loss = 3.147683805147807
# sample_0_words = ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4373278617858887
# ..............................................................................................
# epoch 471: train_loss = 3.150822011311849
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'and', 'red', 'and', 'red', 'shirt', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'in', 'a', 'baseball', 'baseball', 'shirt', 'and', 'baseball', 'uniform', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.175663709640503
# ..............................................................................................
# epoch 472: train_loss = 3.2019736013412476
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'in', 'a', 'baseball', 'baseball', 'baseball', 'game', 'ENDOFSEQ']
# validation_loss = 3.3617911338806152
# ..............................................................................................
# epoch 473: train_loss = 3.187868686358134
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.394167423248291
# ..............................................................................................
# epoch 474: train_loss = 3.1885087985992433
# sample_0_words = ['a', 'man', 'is', 'sitting', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.360342025756836
# ..............................................................................................
# epoch 475: train_loss = 3.1520480902989707
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4007813930511475
# ..............................................................................................
# epoch 476: train_loss = 3.2136728118260702
# sample_0_words = ['a', 'man', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3931236267089844
# ..............................................................................................
# epoch 477: train_loss = 3.1928920863469443
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'in', 'a', 'baseball', 'shirt', 'and', 'baseball', 'uniform', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4657464027404785
# ..............................................................................................
# epoch 478: train_loss = 3.198124258041382
# sample_0_words = ['a', 'man', 'is', 'walking', 'on', 'a', 'red', 'ball', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3137738704681396
# ..............................................................................................
# epoch 479: train_loss = 3.2630954675674437
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4121482372283936
# ..............................................................................................
# epoch 480: train_loss = 3.1956467215220132
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.2172529697418213
# ..............................................................................................
# epoch 481: train_loss = 3.230366984367371
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'baseball', 'player', 'baseball', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.594083309173584
# ..............................................................................................
# epoch 482: train_loss = 3.1223019278844197
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.5096137523651123
# ..............................................................................................
# epoch 483: train_loss = 3.1739854666392007
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'baseball', 'player', 'baseball', 'player', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4590039253234863
# ..............................................................................................
# epoch 484: train_loss = 3.2401432876586913
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4535298347473145
# ..............................................................................................
# epoch 485: train_loss = 3.2216925843556723
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.2951645851135254
# ..............................................................................................
# epoch 486: train_loss = 3.245019480705261
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.468186616897583
# ..............................................................................................
# epoch 487: train_loss = 3.182506601969401
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.5252633094787598
# ..............................................................................................
# epoch 488: train_loss = 3.197037314414978
# sample_0_words = ['a', 'man', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.278475761413574
# ..............................................................................................
# epoch 489: train_loss = 3.1690230846405028
# sample_0_words = ['a', 'man', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4086475372314453
# ..............................................................................................
# epoch 490: train_loss = 3.2494916480382283
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.366831064224243
# ..............................................................................................
# epoch 491: train_loss = 3.199147623062134
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.403639554977417
# ..............................................................................................
# epoch 492: train_loss = 3.2041265563964845
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'playing', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.355583906173706
# ..............................................................................................
# epoch 493: train_loss = 3.173399953524272
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3108067512512207
# ..............................................................................................
# epoch 494: train_loss = 3.1753581552505494
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.4665122032165527
# ..............................................................................................
# epoch 495: train_loss = 3.1523533916473387
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3898749351501465
# ..............................................................................................
# epoch 496: train_loss = 3.143924416224162
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.456979513168335
# ..............................................................................................
# epoch 497: train_loss = 3.1893528741200763
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3386423587799072
# ..............................................................................................
# epoch 498: train_loss = 3.1750551767349244
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3289008140563965
# ..............................................................................................
# epoch 499: train_loss = 3.1648390305836998
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'sitting', 'on', 'a', 'red', 'wall', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.335934638977051
# ..............................................................................................
# epoch 500: train_loss = 3.18984969997406
# sample_0_words = ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'walking', 'on', 'a', 'red', 'ball', 'ENDOFSEQ']
# sample_100_words = ['a', 'baseball', 'player', 'is', 'playing', 'baseball', 'ENDOFSEQ']
# validation_loss = 3.3046951293945312

# %%
test_images_filepath = 'flickr/Flickr_Data/Flickr_TextData/Flickr_8k.testImages.txt'
with open(test_images_filepath, 'r') as test_images_file:
    test_images_list = [line.strip() for line in test_images_file]
print("lowest validation loss = {}".format(lowestValidationLoss))    
print ("len(test_images_list) = {}".format(len(test_images_list)))
# Out:
# len(test_images_list) = 1000

# %%
# Load the model that gave the lowest validation loss
lstm_model.load_state_dict(torch.load(best_model_filepath))
# Randomly select some test images
test_image_sample_indices = random.choices(range(len(test_images_list)), k=3)
lstm_model.eval()
test_sample_filepaths = []
test_sample_captions = []
for test_image_sample_index in test_image_sample_indices:
    sample_words = TestSample(test_image_sample_index, test_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
    caption = ' '.join(sample_words)
    test_sample_filepaths.append(os.path.join(imagesFilepath, test_images_list[test_image_sample_index]))
    test_sample_captions.append(caption)

# %%
print (test_sample_captions[1])
IPython.display.Image(test_sample_filepaths[1])

# %%
import nltk
import csv
from nltk.translate.bleu_score import sentence_bleu
from collections import defaultdict


# Load tokenized descriptions
tokenized_descriptions = defaultdict(list)
with open(pretokenized_descriptions_filepath, 'r') as file:
    reader = csv.reader(file)
    next(reader)  # Skip the header row
    for row in reader:
        image_name = row[0]
        caption_indices = []
        for index_str in row[1:]:
            index = int(index_str)
            if index == 2:
                break  # Stop capturing indices when index is 2
            caption_indices.append(index)
        tokenized_descriptions[image_name].append(caption_indices)

# %%
# Function to convert indices to words
def indices_to_words(indices):
    return [index_to_word_dict[index] for index in indices]

# Calculate BLEU score for each test image
total_bleu_score_1 = 0
total_bleu_score_2 = 0
total_bleu_score_3 = 0
total_bleu_score_4 = 0
total_images = len(test_images_list)
lstm_model.eval()
test_image_sample_indices_all = len(test_images_list);

for index in  range(test_image_sample_indices_all):
     sample_words = TestSample(index, test_images_list, image_filename_to_latent_variables, lstm_model,
       index_to_word_dict,
       word_to_embedding_dict,
       sequence_length=40,
       endOfSeqIndex=0,
       useCuda=useCuda)
     description = ' '.join(sample_words)
     candidate_caption = Tokenize(description, nlp)

     reference_captions = [indices_to_words(indices) for indices in tokenized_descriptions[test_images_list[index]]]

     bleu_score_1 = sentence_bleu(reference_captions, candidate_caption, weights=(1, 0, 0, 0))
     bleu_score_2 = sentence_bleu(reference_captions, candidate_caption, weights=(0.5, 0.5, 0, 0))
     bleu_score_3 = sentence_bleu(reference_captions, candidate_caption, weights=(0.33, 0.33, 0.33, 0))
     bleu_score_4 = sentence_bleu(reference_captions, candidate_caption, weights=(0.25, 0.25, 0.25, 0.25))
    
     total_bleu_score_1 += bleu_score_1
     total_bleu_score_2 += bleu_score_2
     total_bleu_score_3 += bleu_score_3
     total_bleu_score_4 += bleu_score_4

average_bleu_score_1 = total_bleu_score_1 / total_images
average_bleu_score_2 = total_bleu_score_2 / total_images
average_bleu_score_3 = total_bleu_score_3 / total_images
average_bleu_score_4 = total_bleu_score_4 / total_images

# average_bleu_score = total_bleu_score / len(test_images)
print("Average BLEU-1 score:", average_bleu_score_1)
print("Average BLEU-2 score:", average_bleu_score_2)
print("Average BLEU-3 score:", average_bleu_score_3)
print("Average BLEU-4 score:", average_bleu_score_4)
# Out:
# Average BLEU-1 score: 0.5176829241708263
# Average BLEU-2 score: 0.3367100738643254
# Average BLEU-3 score: 0.1547620081733169
# Average BLEU-4 score: 0.0549670276848824
